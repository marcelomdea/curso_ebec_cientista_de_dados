# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Programação Funcional
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Função lambda;</li>
#   <li>Função map;</li>
#   <li>Função filter;</li>
#   <li>Função reduce.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 0\. Preparação do ambiente

# %% [markdown]
# Neste exercício vamos trabalhar com o arquivo csv com dados de crédito, definido abaixo. Execute cada uma das células de código para escrever os arquivos na sua máquina virtual.

# %%
# %%writefile credito.csv
# id_vendedor,valor_emprestimos,quantidade_emprestimos,data
# 104271,448.0,1,20161208
# 21476,826.7,3,20161208
# 87440,313.6,3,20161208
# 15980,-8008.0,6,20161208
# 215906,2212.0,5,20161208
# 33696,2771.3,2,20161208
# 33893,2240.0,3,20161208
# 214946,-4151.0,18,20161208
# 123974,2021.95,2,20161208
# 225870,4039.0,2,20161208
# Out:
# Writing credito.csv

# %% [markdown]
# Vamos ler o conteúdo do arquivo em uma lista onde cada elemento é um dicionário representando as linhas do arquivo.

# %%
emprestimos = []
with open(file='./credito.csv', mode='r', encoding='utf8') as fp:
  fp.readline() # cabeçalho
  linha = fp.readline()
  while linha:
    linha_emprestimo = {}
    linha_elementos = linha.strip().split(sep=',')
    linha_emprestimo['id_vendedor'] = linha_elementos[0]
    linha_emprestimo['valor_emprestimos'] = linha_elementos[1]
    linha_emprestimo['quantidade_emprestimos'] = linha_elementos[2]
    linha_emprestimo['data'] = linha_elementos[3]
    emprestimos.append(linha_emprestimo)
    linha = fp.readline()

# %%
for emprestimo in emprestimos:
  print(emprestimo)
# Out:
# {'id_vendedor': '104271', 'valor_emprestimos': '448.0', 'quantidade_emprestimos': '1', 'data': '20161208'}
# {'id_vendedor': '21476', 'valor_emprestimos': '826.7', 'quantidade_emprestimos': '3', 'data': '20161208'}
# {'id_vendedor': '87440', 'valor_emprestimos': '313.6', 'quantidade_emprestimos': '3', 'data': '20161208'}
# {'id_vendedor': '15980', 'valor_emprestimos': '-8008.0', 'quantidade_emprestimos': '6', 'data': '20161208'}
# {'id_vendedor': '215906', 'valor_emprestimos': '2212.0', 'quantidade_emprestimos': '5', 'data': '20161208'}
# {'id_vendedor': '33696', 'valor_emprestimos': '2771.3', 'quantidade_emprestimos': '2', 'data': '20161208'}
# {'id_vendedor': '33893', 'valor_emprestimos': '2240.0', 'quantidade_emprestimos': '3', 'data': '20161208'}
# {'id_vendedor': '214946', 'valor_emprestimos': '-4151.0', 'quantidade_emprestimos': '18', 'data': '20161208'}
# {'id_vendedor': '123974', 'valor_emprestimos': '2021.95', 'quantidade_emprestimos': '2', 'data': '20161208'}
# ...

# %% [markdown]
# ## 1\. Função `map`

# %% [markdown]
# Aplique a função map na lista de `emprestimos` para extrair os valores da chave `valor_emprestimos` na lista `valor_emprestimos_lista`. Faça também a conversão de `str` para `float`.

# %%
valor_emprestimos_lista = map(lambda emprestimo : float(emprestimo['valor_emprestimos']), emprestimos)

# %%
print(list(valor_emprestimos_lista)) # [448.0, 826.7, ..., 4039.0]
# Out:
# [448.0, 826.7, 313.6, -8008.0, 2212.0, 2771.3, 2240.0, -4151.0, 2021.95, 4039.0]

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Função `filter`

# %% [markdown]
# Aplique a função filter na lista de `valor_emprestimos_lista` para filtrar apenas os valores maiores que zero (os valores negativas são erros na base de dados). Salve os valores na lista `valor_emprestimos_lista_filtrada`.

# %%
valor_emprestimos_lista_filtrada = filter(lambda emprestimo: emprestimo > 0, list(map(lambda emprestimo : float(emprestimo['valor_emprestimos']), emprestimos)))

# %%
print(list(valor_emprestimos_lista_filtrada)) # [448.0, 826.7, ..., 4039.0]
# Out:
# [448.0, 826.7, 313.6, 2212.0, 2771.3, 2240.0, 2021.95, 4039.0]

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Função `reduce`

# %% [markdown]
# Com a nossa lista de valores de emprestimo pronta, vamos extrair algumas métricas.

# %% [markdown]
# ### 3\.1\. Função `reduce` para extrair a **soma**

# %% [markdown]
# Aplique a função reduce para somar os elementos da lista `valor_emprestimos_lista_filtrada` na variavel `soma_valor_emprestimos`.

# %%
from functools import reduce

valor_emprestimos_lista_filtrada = filter(lambda emprestimo: emprestimo > 0, list(map(lambda emprestimo : float(emprestimo['valor_emprestimos']), emprestimos)))
soma_valor_emprestimos = reduce(lambda e1 ,e2 : e1+e2, valor_emprestimos_lista_filtrada)

# %%
print(soma_valor_emprestimos) # 14872.550000000001
# Out:
# 14872.550000000001

# %% [markdown]
# ### 3\.2\. Função `reduce` para extrair a **media aritimética**

# %% [markdown]
# Aplique a função reduce para extrair a média aritimética (mais informações [aqui](https://pt.wikipedia.org/wiki/M%C3%A9dia#M%C3%A9dia_aritm%C3%A9tica)) dos elementos da lista `valor_emprestimos_lista_filtrada` na variavel `media_valor_emprestimos`.

# %%
from functools import reduce

valor_emprestimos_lista_filtrada = list(filter(lambda emprestimo: emprestimo > 0, list(map(lambda emprestimo : float(emprestimo['valor_emprestimos']), emprestimos))))
media_valor_emprestimos = reduce(lambda v1 ,v2 : v1+v2, valor_emprestimos_lista_filtrada)

# %%
print(media_valor_emprestimos/len(valor_emprestimos_lista_filtrada)) # 1859.0687500000001
# Out:
# 1859.0687500000001

# %% [markdown]
# ### 3\.3\. (**Desafio**) Função `reduce` para extrair o **desvio padrão**

# %% [markdown]
# Aplique a função reduce para extrair a média aritimética (mais informações [aqui](https://pt.wikipedia.org/wiki/M%C3%A9dia#M%C3%A9dia_aritm%C3%A9tica)) dos elementos da lista `valor_emprestimos_lista_filtrada` na variavel `desvio_padrao_valor_emprestimos`.

# %%
from functools import reduce
import numpy as np

valor_emprestimos_lista_filtrada = list(filter(lambda emprestimo: emprestimo > 0, list(map(lambda emprestimo : float(emprestimo['valor_emprestimos']), emprestimos))))
media = reduce(lambda v1 ,v2 : v1+v2, valor_emprestimos_lista_filtrada)/len(valor_emprestimos_lista_filtrada)
quadrados = list(map(lambda emprestimo: pow(emprestimo-media, 2), valor_emprestimos_lista_filtrada))
soma_quadrados = reduce(lambda v1, v2: v1+v2, quadrados)

desvio_padrao_valor_emprestimos = 1271.997271149785
desvio_padrao_valor_emprestimos_numpy = np.std(valor_emprestimos_lista_filtrada)
desvio_padrao_valor_emprestimos_khanacademy = pow(soma_quadrados/len(valor_emprestimos_lista_filtrada), 1/2)

# %%
print(f'Valor experado: {desvio_padrao_valor_emprestimos}') # 1271.997271149785

print(f'Tentativa com numpy: {desvio_padrao_valor_emprestimos_numpy}')
#https://pt.khanacademy.org/math/statistics-probability/summarizing-quantitative-data/variance-standard-deviation-population/a/calculating-standard-deviation-step-by-step')
print(f'Tentativa com tutorial khanacademy: {desvio_padrao_valor_emprestimos_khanacademy}')
print(f'Tentei {int(desvio_padrao_valor_emprestimos-desvio_padrao_valor_emprestimos_numpy)} vezes mas não deu não Professor!🥺 Mas cheguei perto😃🥲🤨!!😐 Eu acho!!!🤔')
# Out:
# Valor experado: 1271.997271149785
# Tentativa com numpy: 1189.8444963884724
# Tentativa com tutorial khanacademy: 1189.8444963884722
# Tentei 82 vezes mas não deu não Professor!🥺 Mas cheguei perto😃🥲🤨!!😐 Eu acho!!!🤔

# %% [markdown]
# ---
